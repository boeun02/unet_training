# %% [markdown]
# # **Training the UNET**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Import**

# %%
import os
import numpy as np
import cv2
from glob import glob
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger

# %% [markdown]
# **GPU 할당**

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # 필요할 때 메모리를 할당하도록 설정
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
  except RuntimeError as e:
    print(e)

# %% [markdown]
# **Seeding**

# %%
os.environ["PYTHONHASHSEED"] = str(42)
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# **Hyerparameters**

# %%
batch_size = 8
lr = 1e-4 #0.0001
epochs = 100
height = 384
width = 256

# %% [markdown]
# **Path**

# %%
dataset_path = r"/content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug"

files_dir = os.path.join("files", "non-aug")
model_file = os.path.join(r"/content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug", "unet-non-aug.h5")
log_file = os.path.join(files_dir, "log-non-aug.csv")

# %% [markdown]
# **Creating Folder**

# %%
def create_dir(path):
  if not os.path.exists(path):
    os.makedirs(path)

# %%
create_dir(files_dir)

# %% [markdown]
# # **Building UNET**

# %% [markdown]
# **Conv Block**

# %%
def conv_block(inputs, num_filters):
  x = Conv2D(num_filters, 3, padding="same")(inputs)
  x = BatchNormalization()(x)
  x = Activation("relu")(x)

  x = Conv2D(num_filters,3, padding="same")(x)
  x = BatchNormalization()(x)
  x = Activation("relu")(x)

  return x

# %% [markdown]
# **Encoding Block**

# %%
def encoder_block(inputs, num_filters):
  x = conv_block(inputs, num_filters)
  p = MaxPool2D((2, 2))(x)
  return x, p

# %% [markdown]
# **Decoder Block**

# %%
def decoder_block(inputs, skip, num_filters):
  x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
  x = Concatenate()([x, skip])
  x = conv_block(x, num_filters)
  return x

# %% [markdown]
# **UNET**

# %%
def build_unet(input_shape):
  inputs = Input(input_shape)

  """Encoder"""
  s1, p1 = encoder_block(inputs, 64)
  s2, p2 = encoder_block(p1, 128)
  s3, p3 = encoder_block(p2, 256)
  s4, p4 = encoder_block(p3, 512)

  """Bridge"""
  b1 = conv_block(p4, 1024)

  """Decoder"""
  d1 = decoder_block(b1, s4, 512)
  d2 = decoder_block(d1, s3, 256)
  d3 = decoder_block(d2, s2, 128)
  d4 = decoder_block(d3, s1, 64)

  outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)
  model = Model(inputs, outputs, name="UNET")
  return model

# %% [markdown]
# # **Dataset Pipeline**

# %% [markdown]
# **Loding the training and validation dataset**

# %%
def load_data(path):
    train_x = sorted(glob(os.path.join(path, "train", "images", "*.jpg")))
    train_y = sorted(glob(os.path.join(path, "train", "masks", "*.png")))

    test_x = sorted(glob(os.path.join(path, "test", "images", "*.jpg")))
    test_y = sorted(glob(os.path.join(path, "test", "masks", "*.png")))
    return (train_x, train_y), (test_x, test_y)

# %% [markdown]
# **Reading Images**

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (256, 384)) # 너비와 높이를 줄입니다.
    x = x / 255.0
    return x

# %% [markdown]
# **Reading Mask**

# %%
def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (256, 384)) # 너비와 높이를 줄입니다.
    x = x / 255.0
    x = np.expand_dims(x, axis=-1)
    return x

# %% [markdown]
# **tf.data pipeline**

# %%
def tf_parse(x, y):
  def _parse(x, y):
    x = read_image(x)
    y = read_mask(y)
    return x, y

  x, y = tf.numpy_function(_parse, [x, y], [tf.float64, tf.float64])
  x.set_shape([height, width, 3])
  y.set_shape([height, width, 1])

  return x, y

# %%
def tf_dataset(x, y, batch=8):
  dataset = tf.data.Dataset.from_tensor_slices((x, y))
  dataset = dataset.map(tf_parse, num_parallel_calls=tf.data.AUTOTUNE)
  dataset = dataset.batch(batch)
  dataset = dataset.prefetch(tf.data.AUTOTUNE)
  return dataset

# %% [markdown]
# **Training**

# %%
(train_x, train_y), (test_x, test_y) = load_data(dataset_path)
print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Test: {len(test_x)} - {len(test_y)}")
# Out:
# Train: 581 - 581
# Test: 101 - 101

# %%
train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
test_dataset = tf_dataset(test_x, test_y, batch=batch_size)

# %%
for x, y in test_dataset:
  print(x.shape, y.shape)
# Out:
# (8, 384, 256, 3) (8, 384, 256, 1)
# (8, 384, 256, 3) (8, 384, 256, 1)
# (8, 384, 256, 3) (8, 384, 256, 1)
# (8, 384, 256, 3) (8, 384, 256, 1)
# (8, 384, 256, 3) (8, 384, 256, 1)
# (8, 384, 256, 3) (8, 384, 256, 1)
# (8, 384, 256, 3) (8, 384, 256, 1)
# (8, 384, 256, 3) (8, 384, 256, 1)
# (8, 384, 256, 3) (8, 384, 256, 1)
# (8, 384, 256, 3) (8, 384, 256, 1)
# (8, 384, 256, 3) (8, 384, 256, 1)
# (8, 384, 256, 3) (8, 384, 256, 1)
# (5, 384, 256, 3) (5, 384, 256, 1)

# %%
input_shape = (height, width, 3)
model = build_unet(input_shape)

# %%
model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 384, 256, 3)]        0         []
#
#  conv2d_19 (Conv2D)          (None, 384, 256, 64)         1792      ['input_2[0][0]']
#
#  batch_normalization_18 (Ba  (None, 384, 256, 64)         256       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 384, 256, 64)         0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 384, 256, 64)         36928     ['activation_18[0][0]']
#
#  batch_normalization_19 (Ba  (None, 384, 256, 64)         256       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 384, 256, 64)         0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  max_pooling2d_4 (MaxPoolin  (None, 192, 128, 64)         0         ['activation_19[0][0]']
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 192, 128, 128)        73856     ['max_pooling2d_4[0][0]']
#
#  batch_normalization_20 (Ba  (None, 192, 128, 128)        512       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 192, 128, 128)        0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 192, 128, 128)        147584    ['activation_20[0][0]']
#
#  batch_normalization_21 (Ba  (None, 192, 128, 128)        512       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 192, 128, 128)        0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  max_pooling2d_5 (MaxPoolin  (None, 96, 64, 128)          0         ['activation_21[0][0]']
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 96, 64, 256)          295168    ['max_pooling2d_5[0][0]']
#
#  batch_normalization_22 (Ba  (None, 96, 64, 256)          1024      ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 96, 64, 256)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 96, 64, 256)          590080    ['activation_22[0][0]']
#
#  batch_normalization_23 (Ba  (None, 96, 64, 256)          1024      ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 96, 64, 256)          0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  max_pooling2d_6 (MaxPoolin  (None, 48, 32, 256)          0         ['activation_23[0][0]']
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 48, 32, 512)          1180160   ['max_pooling2d_6[0][0]']
#
#  batch_normalization_24 (Ba  (None, 48, 32, 512)          2048      ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 48, 32, 512)          0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 48, 32, 512)          2359808   ['activation_24[0][0]']
#
#  batch_normalization_25 (Ba  (None, 48, 32, 512)          2048      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 48, 32, 512)          0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  max_pooling2d_7 (MaxPoolin  (None, 24, 16, 512)          0         ['activation_25[0][0]']
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 24, 16, 1024)         4719616   ['max_pooling2d_7[0][0]']
#
#  batch_normalization_26 (Ba  (None, 24, 16, 1024)         4096      ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 24, 16, 1024)         0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 24, 16, 1024)         9438208   ['activation_26[0][0]']
#
#  batch_normalization_27 (Ba  (None, 24, 16, 1024)         4096      ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 24, 16, 1024)         0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_transpose_4 (Conv2D  (None, 48, 32, 512)          2097664   ['activation_27[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 48, 32, 1024)         0         ['conv2d_transpose_4[0][0]',
#  )                                                                   'activation_25[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 48, 32, 512)          4719104   ['concatenate_4[0][0]']
#
#  batch_normalization_28 (Ba  (None, 48, 32, 512)          2048      ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 48, 32, 512)          0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 48, 32, 512)          2359808   ['activation_28[0][0]']
#
#  batch_normalization_29 (Ba  (None, 48, 32, 512)          2048      ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 48, 32, 512)          0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_transpose_5 (Conv2D  (None, 96, 64, 256)          524544    ['activation_29[0][0]']
#  Transpose)
#
#  concatenate_5 (Concatenate  (None, 96, 64, 512)          0         ['conv2d_transpose_5[0][0]',
#  )                                                                   'activation_23[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 96, 64, 256)          1179904   ['concatenate_5[0][0]']
#
#  batch_normalization_30 (Ba  (None, 96, 64, 256)          1024      ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 96, 64, 256)          0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 96, 64, 256)          590080    ['activation_30[0][0]']
#
#  batch_normalization_31 (Ba  (None, 96, 64, 256)          1024      ['conv2d_32[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 96, 64, 256)          0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_transpose_6 (Conv2D  (None, 192, 128, 128)        131200    ['activation_31[0][0]']
#  Transpose)
#
#  concatenate_6 (Concatenate  (None, 192, 128, 256)        0         ['conv2d_transpose_6[0][0]',
#  )                                                                   'activation_21[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 192, 128, 128)        295040    ['concatenate_6[0][0]']
#
#  batch_normalization_32 (Ba  (None, 192, 128, 128)        512       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 192, 128, 128)        0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 192, 128, 128)        147584    ['activation_32[0][0]']
#
#  batch_normalization_33 (Ba  (None, 192, 128, 128)        512       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 192, 128, 128)        0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_transpose_7 (Conv2D  (None, 384, 256, 64)         32832     ['activation_33[0][0]']
#  Transpose)
#
#  concatenate_7 (Concatenate  (None, 384, 256, 128)        0         ['conv2d_transpose_7[0][0]',
#  )                                                                   'activation_19[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 384, 256, 64)         73792     ['concatenate_7[0][0]']
#
#  batch_normalization_34 (Ba  (None, 384, 256, 64)         256       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 384, 256, 64)         0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 384, 256, 64)         36928     ['activation_34[0][0]']
#
#  batch_normalization_35 (Ba  (None, 384, 256, 64)         256       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 384, 256, 64)         0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 384, 256, 1)          65        ['activation_35[0][0]']
#
# ==================================================================================================
# Total params: 31055297 (118.47 MB)
# Trainable params: 31043521 (118.42 MB)
# Non-trainable params: 11776 (46.00 KB)
# __________________________________________________________________________________________________

# %%
opt = tf.keras.optimizers.Adam(lr)

model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["acc"])

# %%
callbacks = [
    ModelCheckpoint(model_file, verbose=1, save_best_only=True, monitor='val_loss'),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=4),
    CSVLogger(log_file),
    EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False)
]

# %%
model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=epochs,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 73/73 [==============================] - ETA: 0s - loss: 0.3537 - acc: 0.8315
# Epoch 1: val_loss improved from inf to 0.52878, saving model to /content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/unet-non-aug.h5
# 73/73 [==============================] - 66s 770ms/step - loss: 0.3537 - acc: 0.8315 - val_loss: 0.5288 - val_acc: 0.8732 - lr: 1.0000e-04
# Epoch 2/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1958 - acc: 0.8649
# Epoch 2: val_loss improved from 0.52878 to 0.36962, saving model to /content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/unet-non-aug.h5
# 73/73 [==============================] - 60s 815ms/step - loss: 0.1958 - acc: 0.8649 - val_loss: 0.3696 - val_acc: 0.8747 - lr: 1.0000e-04
# Epoch 3/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1662 - acc: 0.8673
# Epoch 3: val_loss improved from 0.36962 to 0.29872, saving model to /content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/unet-non-aug.h5
# 73/73 [==============================] - 60s 818ms/step - loss: 0.1662 - acc: 0.8673 - val_loss: 0.2987 - val_acc: 0.8747 - lr: 1.0000e-04
# Epoch 4/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1512 - acc: 0.8684
# Epoch 4: val_loss improved from 0.29872 to 0.28365, saving model to /content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/unet-non-aug.h5
# 73/73 [==============================] - 60s 818ms/step - loss: 0.1512 - acc: 0.8684 - val_loss: 0.2836 - val_acc: 0.8747 - lr: 1.0000e-04
# Epoch 5/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1411 - acc: 0.8690
# Epoch 5: val_loss improved from 0.28365 to 0.25332, saving model to /content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/unet-non-aug.h5
# 73/73 [==============================] - 60s 823ms/step - loss: 0.1411 - acc: 0.8690 - val_loss: 0.2533 - val_acc: 0.8744 - lr: 1.0000e-04
# Epoch 6/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1329 - acc: 0.8696
# Epoch 6: val_loss improved from 0.25332 to 0.17870, saving model to /content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/unet-non-aug.h5
# 73/73 [==============================] - 61s 825ms/step - loss: 0.1329 - acc: 0.8696 - val_loss: 0.1787 - val_acc: 0.8719 - lr: 1.0000e-04
# Epoch 7/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1282 - acc: 0.8698
# Epoch 7: val_loss improved from 0.17870 to 0.14819, saving model to /content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/unet-non-aug.h5
# 73/73 [==============================] - 60s 823ms/step - loss: 0.1282 - acc: 0.8698 - val_loss: 0.1482 - val_acc: 0.8696 - lr: 1.0000e-04
# Epoch 8/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1227 - acc: 0.8702
# Epoch 8: val_loss improved from 0.14819 to 0.13555, saving model to /content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/unet-non-aug.h5
# 73/73 [==============================] - 60s 819ms/step - loss: 0.1227 - acc: 0.8702 - val_loss: 0.1355 - val_acc: 0.8666 - lr: 1.0000e-04
# Epoch 9/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1176 - acc: 0.8706
# Epoch 9: val_loss improved from 0.13555 to 0.12954, saving model to /content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/unet-non-aug.h5
# 73/73 [==============================] - 60s 813ms/step - loss: 0.1176 - acc: 0.8706 - val_loss: 0.1295 - val_acc: 0.8671 - lr: 1.0000e-04
# Epoch 10/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1139 - acc: 0.8708
# Epoch 10: val_loss improved from 0.12954 to 0.12421, saving model to /content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/unet-non-aug.h5
# 73/73 [==============================] - 61s 828ms/step - loss: 0.1139 - acc: 0.8708 - val_loss: 0.1242 - val_acc: 0.8682 - lr: 1.0000e-04
# Epoch 11/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1119 - acc: 0.8707
# Epoch 11: val_loss did not improve from 0.12421
# 73/73 [==============================] - 56s 760ms/step - loss: 0.1119 - acc: 0.8707 - val_loss: 0.1264 - val_acc: 0.8688 - lr: 1.0000e-04
# Epoch 12/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1079 - acc: 0.8712
# Epoch 12: val_loss improved from 0.12421 to 0.12002, saving model to /content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/unet-non-aug.h5
# 73/73 [==============================] - 60s 819ms/step - loss: 0.1079 - acc: 0.8712 - val_loss: 0.1200 - val_acc: 0.8671 - lr: 1.0000e-04
# Epoch 13/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1054 - acc: 0.8712
# Epoch 13: val_loss improved from 0.12002 to 0.11792, saving model to /content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/unet-non-aug.h5
# 73/73 [==============================] - 60s 825ms/step - loss: 0.1054 - acc: 0.8712 - val_loss: 0.1179 - val_acc: 0.8680 - lr: 1.0000e-04
# Epoch 14/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1033 - acc: 0.8713
# Epoch 14: val_loss improved from 0.11792 to 0.11647, saving model to /content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/unet-non-aug.h5
# 73/73 [==============================] - 60s 819ms/step - loss: 0.1033 - acc: 0.8713 - val_loss: 0.1165 - val_acc: 0.8673 - lr: 1.0000e-04
# Epoch 15/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1010 - acc: 0.8715
# Epoch 15: val_loss improved from 0.11647 to 0.11619, saving model to /content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/unet-non-aug.h5
# 73/73 [==============================] - 60s 821ms/step - loss: 0.1010 - acc: 0.8715 - val_loss: 0.1162 - val_acc: 0.8671 - lr: 1.0000e-04
# Epoch 16/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0990 - acc: 0.8717
# Epoch 16: val_loss did not improve from 0.11619
# 73/73 [==============================] - 56s 759ms/step - loss: 0.0990 - acc: 0.8717 - val_loss: 0.1182 - val_acc: 0.8672 - lr: 1.0000e-04
# Epoch 17/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0982 - acc: 0.8715
# Epoch 17: val_loss improved from 0.11619 to 0.11295, saving model to /content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/unet-non-aug.h5
# 73/73 [==============================] - 60s 818ms/step - loss: 0.0982 - acc: 0.8715 - val_loss: 0.1130 - val_acc: 0.8684 - lr: 1.0000e-04
# Epoch 18/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0963 - acc: 0.8718
# Epoch 18: val_loss improved from 0.11295 to 0.11138, saving model to /content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/unet-non-aug.h5
# 73/73 [==============================] - 60s 820ms/step - loss: 0.0963 - acc: 0.8718 - val_loss: 0.1114 - val_acc: 0.8674 - lr: 1.0000e-04
# Epoch 19/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0950 - acc: 0.8719
# Epoch 19: val_loss did not improve from 0.11138
# 73/73 [==============================] - 56s 762ms/step - loss: 0.0950 - acc: 0.8719 - val_loss: 0.1120 - val_acc: 0.8672 - lr: 1.0000e-04
# Epoch 20/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0941 - acc: 0.8719
# Epoch 20: val_loss improved from 0.11138 to 0.11002, saving model to /content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/unet-non-aug.h5
# 73/73 [==============================] - 60s 817ms/step - loss: 0.0941 - acc: 0.8719 - val_loss: 0.1100 - val_acc: 0.8683 - lr: 1.0000e-04
# Epoch 21/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0933 - acc: 0.8719
# Epoch 21: val_loss did not improve from 0.11002
# 73/73 [==============================] - 56s 762ms/step - loss: 0.0933 - acc: 0.8719 - val_loss: 0.1101 - val_acc: 0.8690 - lr: 1.0000e-04
# Epoch 22/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0924 - acc: 0.8720
# Epoch 22: val_loss did not improve from 0.11002
# 73/73 [==============================] - 55s 757ms/step - loss: 0.0924 - acc: 0.8720 - val_loss: 0.1104 - val_acc: 0.8676 - lr: 1.0000e-04
# Epoch 23/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0906 - acc: 0.8723
# Epoch 23: val_loss did not improve from 0.11002
# 73/73 [==============================] - 56s 760ms/step - loss: 0.0906 - acc: 0.8723 - val_loss: 0.1104 - val_acc: 0.8676 - lr: 1.0000e-04
# Epoch 24/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0898 - acc: 0.8723
# Epoch 24: val_loss did not improve from 0.11002
# 73/73 [==============================] - 55s 756ms/step - loss: 0.0898 - acc: 0.8723 - val_loss: 0.1109 - val_acc: 0.8670 - lr: 1.0000e-04
# Epoch 25/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0889 - acc: 0.8725
# Epoch 25: val_loss improved from 0.11002 to 0.10766, saving model to /content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/unet-non-aug.h5
# 73/73 [==============================] - 60s 820ms/step - loss: 0.0889 - acc: 0.8725 - val_loss: 0.1077 - val_acc: 0.8675 - lr: 1.0000e-05
# Epoch 26/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0875 - acc: 0.8729
# Epoch 26: val_loss did not improve from 0.10766
# 73/73 [==============================] - 56s 763ms/step - loss: 0.0875 - acc: 0.8729 - val_loss: 0.1078 - val_acc: 0.8679 - lr: 1.0000e-05
# Epoch 27/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0868 - acc: 0.8730
# Epoch 27: val_loss did not improve from 0.10766
# 73/73 [==============================] - 55s 756ms/step - loss: 0.0868 - acc: 0.8730 - val_loss: 0.1081 - val_acc: 0.8680 - lr: 1.0000e-05
# Epoch 28/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0863 - acc: 0.8731
# Epoch 28: val_loss did not improve from 0.10766
# 73/73 [==============================] - 55s 758ms/step - loss: 0.0863 - acc: 0.8731 - val_loss: 0.1085 - val_acc: 0.8680 - lr: 1.0000e-05
# Epoch 29/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0859 - acc: 0.8732
# Epoch 29: val_loss did not improve from 0.10766
# 73/73 [==============================] - 56s 759ms/step - loss: 0.0859 - acc: 0.8732 - val_loss: 0.1089 - val_acc: 0.8680 - lr: 1.0000e-05
# Epoch 30/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0856 - acc: 0.8733
# Epoch 30: val_loss did not improve from 0.10766
# 73/73 [==============================] - 56s 759ms/step - loss: 0.0856 - acc: 0.8733 - val_loss: 0.1095 - val_acc: 0.8681 - lr: 1.0000e-06
# Epoch 31/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0854 - acc: 0.8734
# Epoch 31: val_loss did not improve from 0.10766
# 73/73 [==============================] - 56s 758ms/step - loss: 0.0854 - acc: 0.8734 - val_loss: 0.1098 - val_acc: 0.8681 - lr: 1.0000e-06
# Epoch 32/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0854 - acc: 0.8734
# Epoch 32: val_loss did not improve from 0.10766
# 73/73 [==============================] - 56s 758ms/step - loss: 0.0854 - acc: 0.8734 - val_loss: 0.1100 - val_acc: 0.8680 - lr: 1.0000e-06
# Epoch 33/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0853 - acc: 0.8734
# Epoch 33: val_loss did not improve from 0.10766
# 73/73 [==============================] - 56s 761ms/step - loss: 0.0853 - acc: 0.8734 - val_loss: 0.1101 - val_acc: 0.8680 - lr: 1.0000e-06
# Epoch 34/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0852 - acc: 0.8734
# Epoch 34: val_loss did not improve from 0.10766
# 73/73 [==============================] - 56s 759ms/step - loss: 0.0852 - acc: 0.8734 - val_loss: 0.1102 - val_acc: 0.8680 - lr: 1.0000e-07
# Epoch 35/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0852 - acc: 0.8734
# Epoch 35: val_loss did not improve from 0.10766
# 73/73 [==============================] - 56s 760ms/step - loss: 0.0852 - acc: 0.8734 - val_loss: 0.1102 - val_acc: 0.8680 - lr: 1.0000e-07
# Epoch 36/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0852 - acc: 0.8734
# Epoch 36: val_loss did not improve from 0.10766
# 73/73 [==============================] - 55s 757ms/step - loss: 0.0852 - acc: 0.8734 - val_loss: 0.1102 - val_acc: 0.8680 - lr: 1.0000e-07
# Epoch 37/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0852 - acc: 0.8734
# Epoch 37: val_loss did not improve from 0.10766
# 73/73 [==============================] - 56s 758ms/step - loss: 0.0852 - acc: 0.8734 - val_loss: 0.1103 - val_acc: 0.8680 - lr: 1.0000e-07
# Epoch 38/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0852 - acc: 0.8734
# Epoch 38: val_loss did not improve from 0.10766
# 73/73 [==============================] - 55s 758ms/step - loss: 0.0852 - acc: 0.8734 - val_loss: 0.1103 - val_acc: 0.8680 - lr: 1.0000e-08
# Epoch 39/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0852 - acc: 0.8734
# Epoch 39: val_loss did not improve from 0.10766
# 73/73 [==============================] - 55s 758ms/step - loss: 0.0852 - acc: 0.8734 - val_loss: 0.1103 - val_acc: 0.8680 - lr: 1.0000e-08
# Epoch 40/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0852 - acc: 0.8734
# Epoch 40: val_loss did not improve from 0.10766
# 73/73 [==============================] - 55s 756ms/step - loss: 0.0852 - acc: 0.8734 - val_loss: 0.1103 - val_acc: 0.8680 - lr: 1.0000e-08
# Epoch 41/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0852 - acc: 0.8734
# Epoch 41: val_loss did not improve from 0.10766
# 73/73 [==============================] - 55s 757ms/step - loss: 0.0852 - acc: 0.8734 - val_loss: 0.1103 - val_acc: 0.8680 - lr: 1.0000e-08
# Epoch 42/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0852 - acc: 0.8734
# Epoch 42: val_loss did not improve from 0.10766
# 73/73 [==============================] - 55s 758ms/step - loss: 0.0852 - acc: 0.8734 - val_loss: 0.1103 - val_acc: 0.8680 - lr: 1.0000e-09
# Epoch 43/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0852 - acc: 0.8734
# Epoch 43: val_loss did not improve from 0.10766
# 73/73 [==============================] - 56s 758ms/step - loss: 0.0852 - acc: 0.8734 - val_loss: 0.1103 - val_acc: 0.8680 - lr: 1.0000e-09
# Epoch 44/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0852 - acc: 0.8734
# Epoch 44: val_loss did not improve from 0.10766
# 73/73 [==============================] - 56s 760ms/step - loss: 0.0852 - acc: 0.8734 - val_loss: 0.1103 - val_acc: 0.8680 - lr: 1.0000e-09
# Epoch 45/100
# 73/73 [==============================] - ETA: 0s - loss: 0.0852 - acc: 0.8734
# Epoch 45: val_loss did not improve from 0.10766
# 73/73 [==============================] - 56s 760ms/step - loss: 0.0852 - acc: 0.8734 - val_loss: 0.1103 - val_acc: 0.8680 - lr: 1.0000e-09
