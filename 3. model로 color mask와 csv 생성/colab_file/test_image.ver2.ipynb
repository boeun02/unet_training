# %% [markdown]
# **전에 ver.1은 단일 클래스 분류 기준 코드이고 이번 코드는 다중 클래스 분류 기준임. 또한 각 클래스 별로 색상을 입히도록 수정했으며, 각 클래스마다 csv 파일이 mask와 같이 출력되게끔 설계함.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import time
import numpy as np
import cv2
from glob import glob
from tqdm import tqdm
import tensorflow as tf
import csv
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 384, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 384, 256, 64)         1792      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 384, 256, 64)         256       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 384, 256, 64)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 384, 256, 64)         36928     ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 384, 256, 64)         256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 384, 256, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 192, 128, 64)         0         ['activation_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 192, 128, 128)        73856     ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (Bat  (None, 192, 128, 128)        512       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 192, 128, 128)        0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 192, 128, 128)        147584    ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 192, 128, 128)        512       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 192, 128, 128)        0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 96, 64, 128)          0         ['activation_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 96, 64, 256)          295168    ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 96, 64, 256)          1024      ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 96, 64, 256)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 96, 64, 256)          590080    ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 96, 64, 256)          1024      ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 96, 64, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 48, 32, 256)          0         ['activation_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 48, 32, 512)          1180160   ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (Bat  (None, 48, 32, 512)          2048      ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 48, 32, 512)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 48, 32, 512)          2359808   ['activation_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 48, 32, 512)          2048      ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 48, 32, 512)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 24, 16, 512)          0         ['activation_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 24, 16, 1024)         4719616   ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (Bat  (None, 24, 16, 1024)         4096      ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 24, 16, 1024)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 24, 16, 1024)         9438208   ['activation_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 24, 16, 1024)         4096      ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 24, 16, 1024)         0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  tf.compat.v1.shape (TFOpLa  (4,)                         0         ['activation_7[0][0]']
#  mbda)
#
#  tf.compat.v1.shape_1 (TFOp  (4,)                         0         ['activation_7[0][0]']
#  Lambda)
#
#  conv2d_transpose (Conv2DTr  (None, 48, 32, 512)          2097664   ['activation_9[0][0]']
#  anspose)
#
#  tf.__operators__.getitem (  ()                           0         ['tf.compat.v1.shape[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_1  ()                           0         ['tf.compat.v1.shape_1[0][0]']
#   (SlicingOpLambda)
#
#  tf.image.resize (TFOpLambd  (None, 48, 32, 512)          0         ['conv2d_transpose[0][0]',
#  a)                                                                  'tf.__operators__.getitem[0][
#                                                                     0]',
#                                                                      'tf.__operators__.getitem_1[0
#                                                                     ][0]']
#
#  concatenate (Concatenate)   (None, 48, 32, 1024)         0         ['tf.image.resize[0][0]',
#                                                                      'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 48, 32, 512)          4719104   ['concatenate[0][0]']
#
#  batch_normalization_10 (Ba  (None, 48, 32, 512)          2048      ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 48, 32, 512)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 48, 32, 512)          2359808   ['activation_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 48, 32, 512)          2048      ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 48, 32, 512)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  tf.compat.v1.shape_2 (TFOp  (4,)                         0         ['activation_5[0][0]']
#  Lambda)
#
#  tf.compat.v1.shape_3 (TFOp  (4,)                         0         ['activation_5[0][0]']
#  Lambda)
#
#  conv2d_transpose_1 (Conv2D  (None, 96, 64, 256)          524544    ['activation_11[0][0]']
#  Transpose)
#
#  tf.__operators__.getitem_2  ()                           0         ['tf.compat.v1.shape_2[0][0]']
#   (SlicingOpLambda)
#
#  tf.__operators__.getitem_3  ()                           0         ['tf.compat.v1.shape_3[0][0]']
#   (SlicingOpLambda)
#
#  tf.image.resize_1 (TFOpLam  (None, 96, 64, 256)          0         ['conv2d_transpose_1[0][0]',
#  bda)                                                                'tf.__operators__.getitem_2[0
#                                                                     ][0]',
#                                                                      'tf.__operators__.getitem_3[0
#                                                                     ][0]']
#
#  concatenate_1 (Concatenate  (None, 96, 64, 512)          0         ['tf.image.resize_1[0][0]',
#  )                                                                   'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 96, 64, 256)          1179904   ['concatenate_1[0][0]']
#
#  batch_normalization_12 (Ba  (None, 96, 64, 256)          1024      ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 96, 64, 256)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 96, 64, 256)          590080    ['activation_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 96, 64, 256)          1024      ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 96, 64, 256)          0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  tf.compat.v1.shape_4 (TFOp  (4,)                         0         ['activation_3[0][0]']
#  Lambda)
#
#  tf.compat.v1.shape_5 (TFOp  (4,)                         0         ['activation_3[0][0]']
#  Lambda)
#
#  conv2d_transpose_2 (Conv2D  (None, 192, 128, 128)        131200    ['activation_13[0][0]']
#  Transpose)
#
#  tf.__operators__.getitem_4  ()                           0         ['tf.compat.v1.shape_4[0][0]']
#   (SlicingOpLambda)
#
#  tf.__operators__.getitem_5  ()                           0         ['tf.compat.v1.shape_5[0][0]']
#   (SlicingOpLambda)
#
#  tf.image.resize_2 (TFOpLam  (None, 192, 128, 128)        0         ['conv2d_transpose_2[0][0]',
#  bda)                                                                'tf.__operators__.getitem_4[0
#                                                                     ][0]',
#                                                                      'tf.__operators__.getitem_5[0
#                                                                     ][0]']
#
#  concatenate_2 (Concatenate  (None, 192, 128, 256)        0         ['tf.image.resize_2[0][0]',
#  )                                                                   'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 192, 128, 128)        295040    ['concatenate_2[0][0]']
#
#  batch_normalization_14 (Ba  (None, 192, 128, 128)        512       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 192, 128, 128)        0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 192, 128, 128)        147584    ['activation_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 192, 128, 128)        512       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 192, 128, 128)        0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  tf.compat.v1.shape_6 (TFOp  (4,)                         0         ['activation_1[0][0]']
#  Lambda)
#
#  tf.compat.v1.shape_7 (TFOp  (4,)                         0         ['activation_1[0][0]']
#  Lambda)
#
#  conv2d_transpose_3 (Conv2D  (None, 384, 256, 64)         32832     ['activation_15[0][0]']
#  Transpose)
#
#  tf.__operators__.getitem_6  ()                           0         ['tf.compat.v1.shape_6[0][0]']
#   (SlicingOpLambda)
#
#  tf.__operators__.getitem_7  ()                           0         ['tf.compat.v1.shape_7[0][0]']
#   (SlicingOpLambda)
#
#  tf.image.resize_3 (TFOpLam  (None, 384, 256, 64)         0         ['conv2d_transpose_3[0][0]',
#  bda)                                                                'tf.__operators__.getitem_6[0
#                                                                     ][0]',
#                                                                      'tf.__operators__.getitem_7[0
#                                                                     ][0]']
#
#  concatenate_3 (Concatenate  (None, 384, 256, 128)        0         ['tf.image.resize_3[0][0]',
#  )                                                                   'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 384, 256, 64)         73792     ['concatenate_3[0][0]']
#
#  batch_normalization_16 (Ba  (None, 384, 256, 64)         256       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 384, 256, 64)         0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 384, 256, 64)         36928     ['activation_16[0][0]']
#
#  batch_normalization_17 (Ba  (None, 384, 256, 64)         256       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 384, 256, 64)         0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 384, 256, 13)         845       ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31056077 (118.47 MB)
# Trainable params: 31044301 (118.42 MB)
# Non-trainable params: 11776 (46.00 KB)
# __________________________________________________________________________________________________
# Test Images: 16
#   0%|          | 0/16 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 431ms/step
# Pixel at (0,0): Class 0, Color (0, 0, 0)
# Pixel at (0,100): Class 0, Color (0, 0, 0)
# Pixel at (0,200): Class 0, Color (0, 0, 0)
# Pixel at (100,0): Class 0, Color (0, 0, 0)
# Pixel at (100,100): Class 0, Color (0, 0, 0)
# Pixel at (100,200): Class 0, Color (0, 0, 0)
# Pixel at (200,0): Class 0, Color (0, 0, 0)
# Pixel at (200,100): Class 0, Color (0, 0, 0)
# Pixel at (200,200): Class 0, Color (0, 0, 0)
# Pixel at (300,0): Class 0, Color (0, 0, 0)
# Pixel at (300,100): Class 0, Color (0, 0, 0)
# Pixel at (300,200): Class 11, Color (255, 100, 255)
#   6%|▋         | 1/16 [00:01<00:15,  1.01s/it]
# 1/1 [==============================] - 0s 21ms/step
# Pixel at (0,0): Class 0, Color (0, 0, 0)
# Pixel at (0,100): Class 0, Color (0, 0, 0)
# Pixel at (0,200): Class 0, Color (0, 0, 0)
# Pixel at (100,0): Class 0, Color (0, 0, 0)
# Pixel at (100,100): Class 0, Color (0, 0, 0)
# Pixel at (100,200): Class 0, Color (0, 0, 0)
# Pixel at (200,0): Class 0, Color (0, 0, 0)
# Pixel at (200,100): Class 0, Color (0, 0, 0)
# Pixel at (200,200): Class 0, Color (0, 0, 0)
# Pixel at (300,0): Class 0, Color (0, 0, 0)
# Pixel at (300,100): Class 0, Color (0, 0, 0)
# Pixel at (300,200): Class 0, Color (0, 0, 0)
#  12%|█▎        | 2/16 [00:01<00:10,  1.35it/s]
# 1/1 [==============================] - 0s 21ms/step
# Pixel at (0,0): Class 0, Color (0, 0, 0)
# Pixel at (0,100): Class 0, Color (0, 0, 0)
# Pixel at (0,200): Class 0, Color (0, 0, 0)
# Pixel at (100,0): Class 0, Color (0, 0, 0)
# Pixel at (100,100): Class 0, Color (0, 0, 0)
# Pixel at (100,200): Class 0, Color (0, 0, 0)
# Pixel at (200,0): Class 0, Color (0, 0, 0)
# Pixel at (200,100): Class 3, Color (0, 0, 255)
# Pixel at (200,200): Class 0, Color (0, 0, 0)
# Pixel at (300,0): Class 0, Color (0, 0, 0)
# Pixel at (300,100): Class 0, Color (0, 0, 0)
# Pixel at (300,200): Class 0, Color (0, 0, 0)
#  19%|█▉        | 3/16 [00:01<00:07,  1.72it/s]
# 1/1 [==============================] - 0s 20ms/step
# Pixel at (0,0): Class 0, Color (0, 0, 0)
# Pixel at (0,100): Class 0, Color (0, 0, 0)
# Pixel at (0,200): Class 0, Color (0, 0, 0)
# Pixel at (100,0): Class 0, Color (0, 0, 0)
# Pixel at (100,100): Class 5, Color (255, 0, 255)
# Pixel at (100,200): Class 0, Color (0, 0, 0)
# Pixel at (200,0): Class 0, Color (0, 0, 0)
# Pixel at (200,100): Class 2, Color (0, 255, 0)
# Pixel at (200,200): Class 0, Color (0, 0, 0)
# Pixel at (300,0): Class 0, Color (0, 0, 0)
# Pixel at (300,100): Class 0, Color (0, 0, 0)
# Pixel at (300,200): Class 0, Color (0, 0, 0)
#  25%|██▌       | 4/16 [00:02<00:06,  1.73it/s]
# 1/1 [==============================] - 0s 20ms/step
# Pixel at (0,0): Class 0, Color (0, 0, 0)
# Pixel at (0,100): Class 0, Color (0, 0, 0)
# Pixel at (0,200): Class 0, Color (0, 0, 0)
# Pixel at (100,0): Class 0, Color (0, 0, 0)
# Pixel at (100,100): Class 0, Color (0, 0, 0)
# Pixel at (100,200): Class 0, Color (0, 0, 0)
# Pixel at (200,0): Class 0, Color (0, 0, 0)
# Pixel at (200,100): Class 0, Color (0, 0, 0)
# Pixel at (200,200): Class 0, Color (0, 0, 0)
# Pixel at (300,0): Class 0, Color (0, 0, 0)
# Pixel at (300,100): Class 0, Color (0, 0, 0)
# Pixel at (300,200): Class 0, Color (0, 0, 0)
#  31%|███▏      | 5/16 [00:02<00:05,  1.96it/s]
# 1/1 [==============================] - 0s 22ms/step
# Pixel at (0,0): Class 0, Color (0, 0, 0)
# Pixel at (0,100): Class 0, Color (0, 0, 0)
# Pixel at (0,200): Class 0, Color (0, 0, 0)
# Pixel at (100,0): Class 0, Color (0, 0, 0)
# Pixel at (100,100): Class 0, Color (0, 0, 0)
# Pixel at (100,200): Class 0, Color (0, 0, 0)
# Pixel at (200,0): Class 0, Color (0, 0, 0)
# Pixel at (200,100): Class 2, Color (0, 255, 0)
# Pixel at (200,200): Class 0, Color (0, 0, 0)
# Pixel at (300,0): Class 0, Color (0, 0, 0)
# Pixel at (300,100): Class 0, Color (0, 0, 0)
# Pixel at (300,200): Class 0, Color (0, 0, 0)
#  38%|███▊      | 6/16 [00:03<00:05,  1.86it/s]
# 1/1 [==============================] - 0s 21ms/step
# Pixel at (0,0): Class 0, Color (0, 0, 0)
# Pixel at (0,100): Class 0, Color (0, 0, 0)
# Pixel at (0,200): Class 0, Color (0, 0, 0)
# Pixel at (100,0): Class 0, Color (0, 0, 0)
# Pixel at (100,100): Class 4, Color (255, 255, 0)
# Pixel at (100,200): Class 0, Color (0, 0, 0)
# Pixel at (200,0): Class 0, Color (0, 0, 0)
# Pixel at (200,100): Class 2, Color (0, 255, 0)
# Pixel at (200,200): Class 0, Color (0, 0, 0)
# Pixel at (300,0): Class 0, Color (0, 0, 0)
# Pixel at (300,100): Class 0, Color (0, 0, 0)
# Pixel at (300,200): Class 0, Color (0, 0, 0)
#  44%|████▍     | 7/16 [00:04<00:04,  1.83it/s]
# 1/1 [==============================] - 0s 21ms/step
# Pixel at (0,0): Class 0, Color (0, 0, 0)
# Pixel at (0,100): Class 0, Color (0, 0, 0)
# Pixel at (0,200): Class 0, Color (0, 0, 0)
# Pixel at (100,0): Class 0, Color (0, 0, 0)
# Pixel at (100,100): Class 0, Color (0, 0, 0)
# Pixel at (100,200): Class 0, Color (0, 0, 0)
# Pixel at (200,0): Class 0, Color (0, 0, 0)
# Pixel at (200,100): Class 0, Color (0, 0, 0)
# Pixel at (200,200): Class 0, Color (0, 0, 0)
# Pixel at (300,0): Class 0, Color (0, 0, 0)
# Pixel at (300,100): Class 0, Color (0, 0, 0)
# Pixel at (300,200): Class 0, Color (0, 0, 0)
#  50%|█████     | 8/16 [00:04<00:03,  2.01it/s]
# 1/1 [==============================] - 0s 20ms/step
# Pixel at (0,0): Class 0, Color (0, 0, 0)
# Pixel at (0,100): Class 0, Color (0, 0, 0)
# Pixel at (0,200): Class 0, Color (0, 0, 0)
# Pixel at (100,0): Class 0, Color (0, 0, 0)
# Pixel at (100,100): Class 5, Color (255, 0, 255)
# Pixel at (100,200): Class 0, Color (0, 0, 0)
# Pixel at (200,0): Class 0, Color (0, 0, 0)
# Pixel at (200,100): Class 2, Color (0, 255, 0)
# Pixel at (200,200): Class 0, Color (0, 0, 0)
# Pixel at (300,0): Class 0, Color (0, 0, 0)
# Pixel at (300,100): Class 0, Color (0, 0, 0)
# Pixel at (300,200): Class 0, Color (0, 0, 0)
#  56%|█████▋    | 9/16 [00:05<00:03,  1.93it/s]
# 1/1 [==============================] - 0s 20ms/step
# Pixel at (0,0): Class 0, Color (0, 0, 0)
# Pixel at (0,100): Class 0, Color (0, 0, 0)
# Pixel at (0,200): Class 0, Color (0, 0, 0)
# Pixel at (100,0): Class 0, Color (0, 0, 0)
# Pixel at (100,100): Class 4, Color (255, 255, 0)
# Pixel at (100,200): Class 0, Color (0, 0, 0)
# Pixel at (200,0): Class 0, Color (0, 0, 0)
# Pixel at (200,100): Class 2, Color (0, 255, 0)
# Pixel at (200,200): Class 0, Color (0, 0, 0)
# Pixel at (300,0): Class 0, Color (0, 0, 0)
# Pixel at (300,100): Class 0, Color (0, 0, 0)
# Pixel at (300,200): Class 0, Color (0, 0, 0)
#  62%|██████▎   | 10/16 [00:05<00:03,  1.89it/s]
# 1/1 [==============================] - 0s 20ms/step
# Pixel at (0,0): Class 0, Color (0, 0, 0)
# Pixel at (0,100): Class 0, Color (0, 0, 0)
# Pixel at (0,200): Class 0, Color (0, 0, 0)
# Pixel at (100,0): Class 0, Color (0, 0, 0)
# Pixel at (100,100): Class 6, Color (0, 255, 255)
# Pixel at (100,200): Class 0, Color (0, 0, 0)
# Pixel at (200,0): Class 0, Color (0, 0, 0)
# Pixel at (200,100): Class 3, Color (0, 0, 255)
# Pixel at (200,200): Class 0, Color (0, 0, 0)
# Pixel at (300,0): Class 0, Color (0, 0, 0)
# Pixel at (300,100): Class 0, Color (0, 0, 0)
# Pixel at (300,200): Class 11, Color (255, 100, 255)
#  69%|██████▉   | 11/16 [00:05<00:02,  2.07it/s]
# 1/1 [==============================] - 0s 19ms/step
# Pixel at (0,0): Class 0, Color (0, 0, 0)
# Pixel at (0,100): Class 0, Color (0, 0, 0)
# Pixel at (0,200): Class 0, Color (0, 0, 0)
# Pixel at (100,0): Class 0, Color (0, 0, 0)
# Pixel at (100,100): Class 0, Color (0, 0, 0)
# Pixel at (100,200): Class 0, Color (0, 0, 0)
# Pixel at (200,0): Class 0, Color (0, 0, 0)
# Pixel at (200,100): Class 0, Color (0, 0, 0)
# Pixel at (200,200): Class 0, Color (0, 0, 0)
# Pixel at (300,0): Class 0, Color (0, 0, 0)
# Pixel at (300,100): Class 0, Color (0, 0, 0)
# Pixel at (300,200): Class 0, Color (0, 0, 0)
#  75%|███████▌  | 12/16 [00:06<00:02,  1.95it/s]
# 1/1 [==============================] - 0s 20ms/step
# Pixel at (0,0): Class 0, Color (0, 0, 0)
# Pixel at (0,100): Class 0, Color (0, 0, 0)
# Pixel at (0,200): Class 0, Color (0, 0, 0)
# Pixel at (100,0): Class 0, Color (0, 0, 0)
# Pixel at (100,100): Class 4, Color (255, 255, 0)
# Pixel at (100,200): Class 0, Color (0, 0, 0)
# Pixel at (200,0): Class 0, Color (0, 0, 0)
# Pixel at (200,100): Class 2, Color (0, 255, 0)
# Pixel at (200,200): Class 0, Color (0, 0, 0)
# Pixel at (300,0): Class 0, Color (0, 0, 0)
# Pixel at (300,100): Class 0, Color (0, 0, 0)
# Pixel at (300,200): Class 11, Color (255, 100, 255)
#  81%|████████▏ | 13/16 [00:06<00:01,  2.11it/s]
# 1/1 [==============================] - 0s 19ms/step
# Pixel at (0,0): Class 0, Color (0, 0, 0)
# Pixel at (0,100): Class 0, Color (0, 0, 0)
# Pixel at (0,200): Class 0, Color (0, 0, 0)
# Pixel at (100,0): Class 0, Color (0, 0, 0)
# Pixel at (100,100): Class 6, Color (0, 255, 255)
# Pixel at (100,200): Class 0, Color (0, 0, 0)
# Pixel at (200,0): Class 0, Color (0, 0, 0)
# Pixel at (200,100): Class 3, Color (0, 0, 255)
# Pixel at (200,200): Class 0, Color (0, 0, 0)
# Pixel at (300,0): Class 0, Color (0, 0, 0)
# Pixel at (300,100): Class 0, Color (0, 0, 0)
# Pixel at (300,200): Class 0, Color (0, 0, 0)
#  88%|████████▊ | 14/16 [00:07<00:00,  2.01it/s]
# 1/1 [==============================] - 0s 20ms/step
# Pixel at (0,0): Class 0, Color (0, 0, 0)
# Pixel at (0,100): Class 0, Color (0, 0, 0)
# Pixel at (0,200): Class 0, Color (0, 0, 0)
# Pixel at (100,0): Class 0, Color (0, 0, 0)
# Pixel at (100,100): Class 5, Color (255, 0, 255)
# Pixel at (100,200): Class 0, Color (0, 0, 0)
# Pixel at (200,0): Class 0, Color (0, 0, 0)
# Pixel at (200,100): Class 2, Color (0, 255, 0)
# Pixel at (200,200): Class 0, Color (0, 0, 0)
# Pixel at (300,0): Class 0, Color (0, 0, 0)
# Pixel at (300,100): Class 0, Color (0, 0, 0)
# Pixel at (300,200): Class 0, Color (0, 0, 0)
#  94%|█████████▍| 15/16 [00:08<00:00,  1.86it/s]
# 1/1 [==============================] - 0s 23ms/step
# Pixel at (0,0): Class 0, Color (0, 0, 0)
# Pixel at (0,100): Class 0, Color (0, 0, 0)
# Pixel at (0,200): Class 0, Color (0, 0, 0)
# Pixel at (100,0): Class 0, Color (0, 0, 0)
# Pixel at (100,100): Class 0, Color (0, 0, 0)
# Pixel at (100,200): Class 0, Color (0, 0, 0)
# Pixel at (200,0): Class 0, Color (0, 0, 0)
# Pixel at (200,100): Class 3, Color (0, 0, 255)
# Pixel at (200,200): Class 0, Color (0, 0, 0)
# Pixel at (300,0): Class 0, Color (0, 0, 0)
# Pixel at (300,100): Class 0, Color (0, 0, 0)
# Pixel at (300,200): Class 0, Color (0, 0, 0)
# 100%|██████████| 16/16 [00:08<00:00,  1.88it/s]
# Mean Time: 0.13156 - Mean FPS: 7.60121

# %%
os.environ["PYTHONHASHSEED"] = str(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
height = 384
width = 256
num_classes = 13

# %%
dataset_path = r"/content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/new/images"
save_path = r"/content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/new/masks"
model_path = r"/content/drive/MyDrive/006_BMS2/0002_latxray_training/dataset/non-aug/unet-non-aug.h5"

# %%
def create_dir (path):
    if not os.path.exists(path):
        os.makedirs(path)

# %%
create_dir(save_path)

# %%
model = tf.keras.models.load_model(model_path)

# %%
model.summary()

# %%
test_x = sorted(glob(os.path.join(dataset_path, "*.jpg")))
print(f"Test Images: {len(test_x)}")

# %%
time_taken = []

# 제공된 클래스 색상 정의 (B, G, R 형식)
class_colors = [
    (0, 0, 0), (255, 0, 0), (0, 255, 0), (0, 0, 255), (255, 255, 0),
    (255, 0, 255), (0, 255, 255), (100, 100, 255),
    (100, 255, 100), (255, 100, 100), (100, 255, 255),
    (255, 100, 255), (255, 255, 100), (100, 100, 100)
]

for x in tqdm(test_x):
    name = x.split("/")[-1]

    x = cv2.imread(x, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (width, height))
    x = x / 255.0
    x = np.expand_dims(x, axis=0)

    start_time = time.time()
    prediction = model.predict(x)[0]
    total_time = time.time() - start_time
    time_taken.append(total_time)

    # 마스크 초기화 (배경을 검은색으로 설정)
    mask = np.zeros((height, width, 3), dtype=np.uint8)

    # 가장 높은 확률을 가진 클래스에 대한 인덱스를 얻습니다
    class_indices = np.argmax(prediction, axis=-1)

    for i in range(height):
      for j in range(width):
          class_idx = class_indices[i, j]
          mask[i, j] = class_colors[class_idx]
          if i % 100 == 0 and j % 100 == 0:  # 로그 출력
              print(f"Pixel at ({i},{j}): Class {class_idx}, Color {class_colors[class_idx]}")


    cv2.imwrite(os.path.join(save_path, name), mask)

     # CSV 파일에 저장할 픽셀별 클래스 정보
    pixel_class_info = []

    for i in range(height):
        for j in range(width):
            class_idx = class_indices[i, j]

            # 각 픽셀의 클래스 정보를 리스트에 추가
            pixel_class_info.append([i, j, class_idx])

    # CSV 파일로 픽셀별 클래스 정보 저장
    csv_filename = os.path.join(save_path, f"{name.split('.')[0]}_class_info.csv")
    with open(csv_filename, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Row", "Column", "Class_Index"])
        writer.writerows(pixel_class_info)

# %%
mean_time = np.mean(time_taken)
mean_fps = 1 / mean_time

# %%
print(f"Mean Time: {mean_time:.5f} - Mean FPS: {mean_fps:.5f}")
